# %% [markdown]
# # Advanced Prompt Engineering — Part B
# Student: Harkirat Kaur Arora
# Purpose: reproducible checks supporting the 25-prompt portfolio.

# %%
prompts = 25
print('Total prompts:', prompts)
assert prompts == 25

# %%
revenue=500000
expenses=80000+150000+120000+25000+20000+30000
profit=revenue-expenses
margin=profit/revenue*100
print('Total expenses:', expenses)
print('Profit:', profit)
print('Profit margin:', margin, '%')

# %%
framework = ['Role','Context','Task','Constraints','Output Format','Evidence']
print(' + '.join(framework))
assert len(framework) == 6

# %%
mapping = {
    'Late delivery':'On-time delivery rate',
    'Damaged products':'Damage rate',
    'Wrong products':'Order accuracy rate',
    'Slow refunds':'Average refund processing time'
}
for issue,kpi in mapping.items(): print(issue, '->', kpi)
